# %%
### importing liberary
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import joblib

# %%
## importing data
data =pd.read_csv('D:/Lecture file/25 th lecture 29 march/Decision Tree  - Assignment -4/iphone_purchase_records.csv')
data.head()
# Out:
#    Gender  Age  Salary  Purchase Iphone
# 0    Male   19   19000                0
# 1    Male   35   20000                0
# 2  Female   26   43000                0
# 3  Female   27   57000                0
# 4    Male   19   76000                0

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['Gender']=data['Gender'].replace({'Male': 0,'Female': 1})
data.head()
# Out:
# C:\Users\ZORO\AppData\Local\Temp\ipykernel_4520\2602679045.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Gender']=data['Gender'].replace({'Male': 0,'Female': 1})
#    Gender  Age  Salary  Purchase Iphone
# 0       0   19   19000                0
# 1       0   35   20000                0
# 2       1   26   43000                0
# 3       1   27   57000                0
# 4       0   19   76000                0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           400 non-null    int64
#  1   Age              400 non-null    int64
#  2   Salary           400 non-null    int64
#  3   Purchase Iphone  400 non-null    int64
# dtypes: int64(4)
# memory usage: 12.6 KB

# %% [markdown]
# ### EDA

# %%
sns.countplot(x ='Gender', data = data)
plt.title("Gender disturubition")
plt.savefig('D:/gender distribution .png')
plt.show()

# %%
sns.countplot(x ='Purchase Iphone', data = data)
plt.title(" Purchase Iphone disturubition")
plt.savefig('D:/Purchase Iphone.png')
plt.show()

# %%
sns.heatmap(data.corr(),annot=True ,cmap='magma')
plt.title(" correlation map ")
plt.savefig('D:/correaltion heatmap.png')

# %%
sns.pairplot(data,hue='Purchase Iphone')

plt.savefig('D:/pairplot.png')

# %%
sns.scatterplot(data = data , x = 'Age' ,y = 'Salary', hue ='Purchase Iphone')
plt.title("scatterplot on salary base")
plt.savefig('D:/scatter plot.png')
